# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# Lane 1 Ranking Signal Analysis
# I have chosen this line because i want to appropriately analyze search signals
# and their relationship with visibility, clicks, engagement, etc.

# I am also interested in improving my data science skills and I believe this will
# be a good start as I wish to create a good EDA as well as utilize simple
# regressions and classifications as these methods interest me.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# I believe this work will improve the decision of where to allocate editorial
# resources for content creation and optimization. This answers what types of content,
# topics, or structural attributes a team should prioritize.

# The output of this project will be acted on by content strategists, SEO managers,
# and editorial teams. They can utilize the practical recommendations in order to
# write, update, or structure pages differently. This will lean into the signals that
# actually receive proper results.

# However, there comes a cost with a wrong recommendation, as a team may experience
# wasted editorial hours and wasted production budgets. This is because if we
# misidentify a weak signal for a strong driver, it will lead to a team spending time
# optimizing attributes that will not yield any clicks or upward movement. This will
# cause the team to miss out on real organic traffic opportunities.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load raw dataset
url = 'https://raw.githubusercontent.com/jlao14/flyrank-week1/refs/heads/main/data/raw/content_refresh_anonymized.csv'
df = pd.read_csv(url)

# Display volume of data
print(f"Dataset Shape: {df.shape[0]} pages across {df.shape[1]} columns.\n")

print("---------------------------\n")

# Display the baseline engagement stats regarding impressions and clicks
print("Baseline Engagement (90 Days)\n")
print(df[['impressions_90d', 'ctr']].describe().loc[['mean', '50%', 'max']])
print("\n")

print("---------------------------\n")

# Display the overall trend direction for content
print("Content Trend Direction\n")
print(df['trend_direction'].value_counts(dropna=False))
print("\n")

# First 3 rows of the dataset to show everything loaded appropriately
df.head(3)

# This is an extremely large dataset with 30000 pages across 44 columns. Therefore,
# I believe that isolating any signal with the help of Python code will provide
# adequate insights. For example, if a page is found with a higher CTR that utilizes
# a specific attribute, I would be able to provide a practical, data-backed
# recommendation for a team to utilize.
# Out:
# Dataset Shape: 30000 pages across 44 columns.
#
# ---------------------------
#
# Baseline Engagement (90 Days)
#
#       impressions_90d         ctr
# mean        5200.3663    0.510733
# 50%          731.0000    0.070000
# max       517715.0000  100.000000
#
#
# ---------------------------
#
# Content Trend Direction
#
# trend_direction
# down      16262
# stable     5962
# up         4388
# new        2236
# flat       1152
# Name: count, dtype: int64
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# What I can claim:
# My work will be able to state observed directional relationships between specific
# safe content signals and engagement metrics. This will be done using effect sizes
# and grouped comparisons. I can also claim measured correlations. This will provide
# an output that can be used for decision support for content and editorial teams.

# What I cannot claim:
# I cannot and will not claim causal proof (e.g., "Adding attribute X causes our
# rankings to increase") as no matter the correlation it does not equate to causality.
# Furthermore, since I am operating purely observationally on output data I will never
# claim to "predict Google" or reverse-engineer a search algorithm factor.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
