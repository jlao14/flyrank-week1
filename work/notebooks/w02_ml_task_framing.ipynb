# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# I believe my lane as an ML task goes under Classification/Scoring.
# Although lane 1 mainly focuses on signal analysis, which means it is my task to identify and determine which signals travel together and influence visibility.
# Therefore, framing this as a classification task allows me to build a simple model to seperate high-performing content from low-performing content, in order to analyze the weight and impact of underlying features.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# My target for this task is to predict a direct, and observed outcome from
# the data. I'd be considering data such as: `ctr`, `scroll_rate`
# or `engagement_rate`.
# However, I must avoid the label trap by never using any defined rules or derived metrics such as `is_declining_label`, `trend_direction`, etc. These should never be used as my target or as features.
# To conclude, the label is going to reflect a real-world action measured during a specific time window.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# My end deliverable would be an observational signal report, so considering this my primary success metrics are effect sizes and grouped comparisons rather than pure predictive accuracy. This can be done by utlizing a simple classification model in order to uncover signals, then using a metric such as **ROC-AUC** to validate that the model has detected a genuine pattern before extracting feature importances. In this case a "good" number would be when the effect size is statistically distinct and meaninful enough to perform a valid and directional content recommendation.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %% [markdown]
# For this task I will be making use of the starter dataset `data/raw/content_refresh_anonymized.csv` This would lead to my unit of analysis being:
#
# One row = One Pseudonymized content item

# %%
# Example of one row
import pandas as pd

# Load Dataset (Uploaded locally)
file_path = 'content_refresh_anonymized.csv'
df = pd.read_csv(file_path)

# Extract the first row
single_row = df.iloc[0]

# Print the row to show columns and data types
print(single_row)
# Out:
# content_id                content_304f48230142
# client_id                    client_f369cb89fc
# search_volume                             10.0
# competition                               0.67
# competition_level                         HIGH
# cpc                                       2.05
# content_type                   keyword article
# main_intent                      transactional
# word_count                              3221.0
# char_count                             20457.0
# provider_used                              NaN
# model_used                    gemini-2.5-flash
# impressions_90d                           3803
# clicks_90d                                  29
# pageviews_90d                               22
# sessions_90d                                17
# users_90d                                   16
# engaged_sessions_90d                         1
# ai_sessions_90d                              0
# scroll_events_90d                            1
# ...

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# An *if-statement* would fail here because the signals that drive visibility and engagement are tangled, numerous, as well as constantly shifting.
#
# We can take an example from the dataset, if i were to attempt to write a fixed rule comparing `scroll_rate` and `ai_traffic_pct`. It would be diffcult correlating engagement as these variables can genuinely exceeed 100% because their numerators and denominators originate from completely different measurement systems. Furthermore, missing data varies wildly by content type, and client histories have vastly different depths, meaning a hardcoded rule would misinterpret zero-filled missing values as a lack of engagement.
#
# It would be essential to implement statistical methods and machine learning to isolate real effects from a multi-dimensional dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
